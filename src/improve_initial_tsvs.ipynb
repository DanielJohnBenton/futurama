# %%
from shutil import copy2

# %%
from IPython.display import display, HTML

# %%
directory = "transcripts/initial_tsv"

with open(f"{directory}/episodes.tsv", "r", encoding="utf-8") as episodesFile:
    episodesTsv = [line.split("\t") for line in episodesFile.read().splitlines()[1:]]

print(episodesTsv[0:3])
# Out:
# [['Space Pilot 3000', '1', 'Space_Pilot_3000.tsv'], ['The Series Has Landed', '1', 'The_Series_Has_Landed.tsv'], ['I, Roommate', '1', 'I__Roommate.tsv']]

# %%
speakers = []
speakersLookup = {}

for episode in episodesTsv:
    with open(f"{directory}/{episode[2]}", "r", encoding="utf-8") as inFile:
        lines = [line.split("\t") for line in inFile.read().splitlines()[1:]]
    for line in lines:
        speaker = line[0]
        if speaker not in speakersLookup:
            speakersLookup[speaker] = len(speakers)
            speakers.append({
                "SPEAKER": speaker,
                "COUNT": 1
            })
        else:
            speakers[speakersLookup[speaker]]["COUNT"] += 1

speakers.sort(key=lambda x: -x["COUNT"])

# %%
html = "<table><tr><th>SPEAKER</th><th>COUNT</th></tr>"
for speaker in speakers:
    html += f"<tr><td>{speaker['SPEAKER']}</td><td>{speaker['COUNT']}</td></tr>"
html +="</table>"
display(HTML(html))
# Out:
# <table><tr><th>SPEAKER</th><th>COUNT</th></tr><tr><td>Fry</td><td>3779</td></tr><tr><td>Bender</td><td>3395</td></tr><tr><td>Leela</td><td>3009</td></tr><tr><td>Farnsworth</td><td>1447</td></tr><tr><td>Zoidberg</td><td>900</td></tr><tr><td>Amy</td><td>864</td></tr><tr><td>Hermes</td><td>772</td></tr><tr><td>Zapp</td><td>482</td></tr><tr><td>Professor Farnsworth</td><td>280</td></tr><tr><td>Kif</td><td>249</td></tr><tr><td>Mom</td><td>181</td></tr><tr><td>Calculon</td><td>162</td></tr><tr><td>Lrrr</td><td>147</td></tr><tr><td>Cubert</td><td>146</td></tr><tr><td>Nixon</td><td>138</td></tr><tr><td>Nibbler</td><td>105</td></tr><tr><td>Robot Devil</td><td>90</td></tr><tr><td>Mr. Wong</td><td>89</td></tr><tr><td>Dwight</td><td>86</td></tr><tr><td>Elzar</td><td>75</td></tr><tr><td>Morbo</td><td>75</td></tr><tr><td>URL</td><td>72</td></tr><tr><td>Man</td><td>72</td></tr><tr><td>Linda</td><td>72</td></tr><tr><td>Wernstrom</td><td>68</td></tr><tr><td>LaBarbara</td><td>67</td></tr><tr><td>Nudar</td><td>62</td></tr><tr><td>Walt</td><td>61</td></tr><tr><td>Donbot</td><td>58</td></tr><tr><td>Scruffy</td><td>57</td></tr><tr><td>Sal</td><td>53</td></tr><tr><td>Announcer</td><td>51</td></tr><tr><td>Bender's ghost</td><td>51</td></tr><tr><td>Smitty</td><td>50</td></tr><tr><td>Clamps</td><td>49</td></tr><tr><td>Roberto</td><td>49</td></tr><tr><td>Coilette</td><td>48</td></tr><tr><td>Narrator</td><td>47</td></tr><tr><td>Poopenmeyer</td><td>46</td></tr><tr><td>Santa</td><td>46</td></tr><tr><td>Tate</td><td>46</td></tr><tr><td>Alcazar</td><td>44</td></tr><tr><td
speakersWithBrackets = [speaker for speaker in speakers if "(" in speaker["SPEAKER"] or ")" in speaker["SPEAKER"] or "{" in speaker["SPEAKER"] or "}" in speaker["SPEAKER"]]
html = "<table><tr><th>SPEAKER</th><th>COUNT</th></tr>"
for speaker in speakersWithBrackets:
    html += f"<tr><td>{speaker['SPEAKER']}</td><td>{speaker['COUNT']}</td></tr>"
html +="</table>"
display(HTML(html))
# Out:
# <table><tr><th>SPEAKER</th><th>COUNT</th></tr><tr><td>Farnsworth (v.o.)</td><td>7</td></tr><tr><td>Hermes (VO)</td><td>6</td></tr><tr><td>Zapp (v.o.)</td><td>6</td></tr><tr><td>Fry (Telepathically)</td><td>5</td></tr><tr><td>Susan (v.o.)</td><td>5</td></tr><tr><td>Fry (confused)</td><td>3</td></tr><tr><td>Amy (sobbing)</td><td>3</td></tr><tr><td>Mom (v.o.)</td><td>3</td></tr><tr><td>Bender (Laughing)</td><td>2</td></tr><tr><td>Amy (Crying)</td><td>2</td></tr><tr><td>Fry (Sobbing)</td><td>2</td></tr><tr><td>Fry (VO)</td><td>2</td></tr><tr><td>Frida (through megaphone)</td><td>2</td></tr><tr><td>Leela (off-screen)</td><td>2</td></tr><tr><td>Bender (off-screen)</td><td>2</td></tr><tr><td>Farnsworth (cont'd)</td><td>2</td></tr><tr><td>Leela (v.o.)</td><td>2</td></tr><tr><td>Farnsworth (VO)</td><td>1</td></tr><tr><td>Barbados Slim (OS)</td><td>1</td></tr><tr><td>Cryogenicist (from Jurassic Bark)</td><td>1</td></tr><tr><td>H.G. Blob (on bill)</td><td>1</td></tr><tr><td>Leela (embarrassed)</td><td>1</td></tr><tr><td>Professor (standing up)</td><td>1</td></tr><tr><td>Wernstrom (standing up)</td><td>1</td></tr><tr><td>The PE Crew (standing up)</td><td>1</td></tr><tr><td>Professor (sitting down)</td><td>1</td></tr><tr><td>Professor (VO)</td><td>1</td></tr><tr><td>Colleen (with two beers in her hands)</td><td>1</td></tr><tr><td>Colleen (looking at one of Wernstrom players)</td><td>1</td></tr><tr><td>Zoidberg (walking by)</td><td>1</td></tr><tr><td>Amy (with Kif)</td><td>1</td></tr><tr><td>Kif (high pitched voice)</td><td>1</td></tr><tr><td>Fry (standing up)</td><td>1</td></tr><tr><td>Bender(VO)</td><td>1</td></tr><tr><td>Hermes (saluting Farnsworth)</td><td>1</td></tr><tr><td>Fry (toasting Colleen)</td><td>1</td></tr><tr><td>Fry (angrily)</td><td>1</td></tr><tr><td>Bender (stammering)</td><td>1</td></tr><tr><td>Bender (within inches of the anomaly)</td><td>1</td></tr><tr><td>Calculon (entering the room)</td><td>1</td></tr><tr><td>Colleen (sobbing)</td><td>1</td></tr><tr><td>Colleen (happily)</td><td>1</td></tr><tr><td>Fatbot (standing outside "Robot Plastic Surgery")</td><td>1</td></tr><tr><td>Farnsworth (sniffing)(VO)</td><td>1</td></tr><tr><td>Leela (sniffing)</td><td>1</td></tr><tr><td>Farnsworth (whispering)</td><td>1</td></tr><tr><td>Wernstrom (while hurling the robot into the anomaly)</td><td>1</td></tr><tr><td>Wernstrom (while opening a barrel labelled "Lab Animals")</td><td>1</td></tr><tr><td>Fry (sobbing)</td><td>1</td></tr><tr><td>Zapp (grabbing/covering his groin)</td><td>1</td></tr><tr><td>Bender (to Calculon)</td><td>1</td></tr><tr><td>Bender (VO)</td><td>1</td></tr><tr><td>Bender (tapping his foot)</td><td>1</td></tr><tr><td>Kif (tinkering with the missile, legs hanging out of the missile bay)</td><td>1</td></tr><tr><td>Bender (interrupting the song)</td><td>1</td></tr><tr><td>Amy (crying)</td><td>1</td></tr><tr><td>Zapp (VO)</td><td>1</td></tr><tr><td>Bender (standing in front of the fireplace)</td><td>1</td></tr><tr><td>Fry (who is now shown on the Jumbotron)</td><td>1</td></tr><tr><td>Leela (pointing a gun at Fry)</td><td>1</td></tr><tr><td>Leela (pointing two guns at Fry)</td><td>1</td></tr><tr><td>Linda (Screaming)</td><td>1</td></tr><tr><td>Farnsworth (Typing on the keyboard.)</td><td>1</td></tr><tr><td>Fry (Raising into the air with clenched fists.)</td><td>1</td></tr><tr><td>Colleen (Confused)</td><td>1</td></tr><tr><td>Fry (Walking with Colleen.)</td><td>1</td></tr><tr><td>Leela (Into her Wristlomojacker)</td><td>1</td></tr><tr><td>Bender (Over Leela's Wristlomojacker)</td><td>1</td></tr><tr><td>Destructor (Leaning against a building)</td><td>1</td></tr><tr><td>Leela (While running away.)</td><td>1</td></tr><tr><td>British Robot (Laughing)</td><td>1</td></tr><tr><td>Calculon (Laughing)</td><td>1</td></tr><tr><td>Zapp (sobbing)</td><td>1</td></tr><tr><td>Farnsworth (With many tentacles behind him)</td><td>1</td></tr><tr><td>Leela (From the doorway)</td><td>1</td></tr><tr><td>Morbo (Crying)</td><td>1</td></tr><tr><td ...

# %%
# Names e.g. Farnsworth have been written in lots of ways
# not all case differences need to be included but in some cases where there are no other textual variations I include a case variation seen in the source
nameMaps = [
    ["Professor Farnsworth", "Farnsworth", "Farnswoth", "Prof. Farnsworth", "Farnsworth (cont'd)", "Farnsworth v.o.", "Farnsowrth", "Professor Farnsoworth"],
    ["Hedonism Bot", "Hedonismbot"],
    ["Kwanzaa Bot", "Kwanzaa-Bot", "Kwanzabot"],
    ["Yivo", "YIVO"],
    ["Richard Nixon's Head", "Nixon", "Nixon's head"],
    ["LaBarbara", "Labarbara"],
    ["ALL", "All"],
    ["Old man", "Old Man"],
    ["Female voice", "Female Voice"],
    ["Suicide booth", "Suicide Booth"],
    ["Hydroponic farmer", "Hydroponic Farmer"],
    ["Underwater house salesman", "Underwater House Salesman"],
    ["Bender doll", "Bender Doll"],
    ["Brown-haired man", "Brown-haired Man"],
    ["Zapp Brannigan", "Zapp"]
]

# %%
# lines with brackets also contain unspoken text
for episode in episodesTsv:
    with open(f"{directory}/{episode[2]}", "r", encoding="utf-8") as inFile:
        lines = [line.split("\t") for line in inFile.read().splitlines()[1:]]
    for line in lines:
        if len(line) < 2:
            continue
        line = line[1]
        if "(" in line or ")" in line or "{" in line or "}" in line:
            print(line)
# Out:
# Whoa, slow down! This place just doesn't feel like home. It just isn't ... cosy.  Ah. I can barely move!  (from inside) It's perfect!
# Mm-hm.  I like your style. I find it very... (whispering) erotic.
# Aww! (whispering to Fry) I'll fire up the grill!
# I can't take it anymore! They've been at it for hours!  (shouting) Give it a rest, you two!
# Invalid selection. (normal voice) Yo, what are you talking about?
# Fry, please--  (from outside) My ponytail's caught in the door.
# No, it isn't! Shut your filthy trap!  (talking) Thank you, Walt. If anyone ever got a hold of anchovy DNA, they could chop out the oil-making gene, stick it in a bunch of Third-World kids and bam! Cheap effective robot oil. Enough to put dear, old Mom out of businness.
# Get his PIN number, you idiots!  (talking) Now I'm off to some charity BS for knocked-up teenage sluts.
# Oh, that's ridiculous! (whispering) I'll take two pounds!
# Lie down on table. I take lungs now, gills come next week.  (shouting) Nurse!
# (reading) Who slurped Hudge the Dewy, who enjoyed a soup composed principally of Throm the Chunky, do solemnly swear to rule with honour and insanity-- Uh, integrity!
# What are you talking about, Bender? She's al--  (muffled) Oh!
# We're gonna die! (calmly) Right?
# (OC) Happy New Year, naked weirdo!
# (OC) Happy New Year, naked weirdo!
# (cab driver) Yes sir.
# (VO) Unfortunately, I had no money from that era. But that's when it hit me - I knew where to find free pizza.
# (VO) That's when it hit me again ...
# (OC)  Explosion in seven, six ...
# (VO) That's when it hit me yet a third time ...
# (on TV) Leelu is a rare, toothed female narwhal who got disoriented and washed up in Atlantic City, as we all do from time to time. But without a mother, she's lost the will to eat.  Come on, take a sip.
# (on TV) In business news, the weak and gullible inhabitants of Earth were plunged into economic depression today as the scammer aliens finished stealing every item of value, including ownership of this station.
# (on TV)
# (VO) ... and as soon as I was out of the scammers' control, I pulled the old switcheroo.
# Hey, you can't (voice slowing)turn me off...
# (SOFT GASP)
# You're moving in with her? Why can't she move in with us?  I could just curl up at the foot of the bed. (WHIMPERING)
# (Gasps) The anomaly!
# So, what's the explanation for you, moron fever? (laughs)
# Bender to crew. I have reached the gateway to another universe. I feel awed and strangely humbled by the momentous solemnity of this occasion. (yelling) Hey, other universe, bite my shiny metal...
# (Gasps) TV's Calculon! (He coughs)
# (laughs) I feel great, and I owe it all to Calculon.  His visit really inspired me.  I finally know what I want to be when I grow up.
# Now that I've teamed up with my friend, Dr. (spiteful tone) Wernstrom, (normal tone) I feel certain we can successfully penetrate the other universe.
# Thank you, thank you. Well deserved. (To Kif) Kif, stand in that hole so I look taller.  (To crowd) Ever since man first left his cave and met a stranger with a different language and a new way of looking at things, the human race has had a dream. To kill him, so we don't have to learn his language or his new way of looking at things.
# Wow, how come humans get to do all the fun stuff? This is exactly the sort of thing that ought to be handled by (whispering) The League of Robots.
# (He laughs.) That's adorable, Bender. You actually believe in the League of Robots?
# Is the horse's name (whispers) Hot Beans?
# Diamondium? (He scoffs.) I could gum through that with my dentures behind my back. My trademarked Diamondillium is twice as hard!
# I know it may seem strange that I have feelings for an octopus monster from another universe. And yes, perhaps it's not the storybook romance that's been crammed down our throats by (quoting the syllables) "Hollywood." But the Monsterpus has loved us from afar since we were amoebas.  Only when the space anomaly opened could it finally express a billion years of longing.
# All in. Call my mighty bid at your peril.  (Telepathically)
# I shall annihilate... Fry hugs him.] (Sobbing:) I just wanted to make my daddy proud.
# On Pluto's moon, Hydra. It's a six-billion-mile par-two. Tough shot, even for a man.  (Leo VO)
# Zilcho. No sign of life or intelligence.  (Telepathically)
# Here's the button here.  (Through megaphone)
# I said no way. (Telepathically): This idiot don't look like he could handle those feministas.
# Does "violet dwarf" rhyme with "men are dorks"? It does through a megaphone. (Telepathically): That reminds me, I've got to tell Leela about that weirdo who wants to save the violet dwarf.
# For me, there are only one '80s.  (VO)
# Am I really just a robot? I mean, I have Leela's memories!  Her opinion of gazelles! (Majestic.)  Her emotions! (Confused and hurt.)
# Now, I've simulated that collision using Shrapnovision(?).
# Ah! I have everything I every wanted. Money, wealth, riches. Yet something's missing. A hot princess with which to get(?) grizzly.
# It's getting cold and smelly. My odor-eaters(?) are going critical.
# Aw, jeez with this, hey?(?)
# Oh, the Colonial Desktop(?).  Well, there's nuthin' we Brits enjoy more dan a good document'ry. Turn on the televiser, Dr. Zoidsmythe.

# %% [markdown]
# #### Steps for improvement per line:
#
# 1. Remove brackets from speakers (ensure matching)
# 2. Correct name variations from speakers (includes case differences)
# 3. Remove colons from speakers (I think only one occurrence of this exists)
# 4. Remove brackets from line text (ensure matching)
#
# For each step trim (`strip`) whitespaces.

# %%
def remove_bracketed_text(text):
    textBracketsRemoved = ""
    bracketLevel = 0
    for character in text:
        if character == "(":
            bracketLevel += 1
        elif character == ")" and bracketLevel >= 1:
            bracketLevel -= 1
        elif bracketLevel == 0:
            textBracketsRemoved += character
    
    return textBracketsRemoved, bracketLevel

# %%
for episode in episodesTsv:
    with open(f"{directory}/{episode[2]}", "r", encoding="utf-8") as inFile:
        lines = [line.split("\t") for line in inFile.read().splitlines()[1:]]
    
    improvedTsv = "SPEAKER\tLINE\n"
    
    for line in lines:
        if len(line) < 2:
            continue
        
        speaker = line[0]
        line = line[1]
        
        if "(" in speaker:
            speakerBracketsRemoved, bracketLevel = remove_bracketed_text(speaker)
            if bracketLevel == 0:
                speaker = speakerBracketsRemoved.strip()
        
        speaker = speaker.replace(":", "")
        
        for mapping in nameMaps:
            mapTo = mapping[0]
            for variation in mapping:
                if speaker.lower() == variation.lower():
                    speaker = mapTo
        
        if "(" in line:
            lineBracketsRemoved, bracketLevel = remove_bracketed_text(line)
            if bracketLevel == 0:
                line = lineBracketsRemoved.strip()
        
        if line == "" or speaker == "":
            continue
        
        improvedTsv += f"{speaker}\t{line}\n"
        
        with open(f"transcripts/improved_tsv/{episode[2]}", "w", encoding="utf-8") as outFile:
            outFile.write(improvedTsv.rstrip())

# %%
copy2(f"{directory}/episodes.tsv", "transcripts/improved_tsv")
print("Copied episodes.tsv as well")
# Out:
# Copied episodes.tsv as well

# %%
directory = "transcripts/improved_tsv"

with open(f"{directory}/episodes.tsv", "r", encoding="utf-8") as episodesFile:
    episodesTsv = [line.split("\t") for line in episodesFile.read().splitlines()[1:]]

print(episodesTsv[0:3])
# Out:
# [['Space Pilot 3000', '1', 'Space_Pilot_3000.tsv'], ['The Series Has Landed', '1', 'The_Series_Has_Landed.tsv'], ['I, Roommate', '1', 'I__Roommate.tsv']]

# %%
speakers = []
speakersLookup = {}

for episode in episodesTsv:
    with open(f"{directory}/{episode[2]}", "r", encoding="utf-8") as inFile:
        lines = [line.split("\t") for line in inFile.read().splitlines()[1:]]
    for line in lines:
        speaker = line[0]
        if speaker not in speakersLookup:
            speakersLookup[speaker] = len(speakers)
            speakers.append({
                "SPEAKER": speaker,
                "COUNT": 1
            })
        else:
            speakers[speakersLookup[speaker]]["COUNT"] += 1

speakers.sort(key=lambda x: -x["COUNT"])

# %%
html = "<table><tr><th>SPEAKER</th><th>COUNT</th></tr>"
for speaker in speakers:
    html += f"<tr><td>{speaker['SPEAKER']}</td><td>{speaker['COUNT']}</td></tr>"
html +="</table>"
display(HTML(html))
# Out:
# <table><tr><th>SPEAKER</th><th>COUNT</th></tr><tr><td>Fry</td><td>3805</td></tr><tr><td>Bender</td><td>3414</td></tr><tr><td>Leela</td><td>3020</td></tr><tr><td>Professor Farnsworth</td><td>1748</td></tr><tr><td>Zoidberg</td><td>903</td></tr><tr><td>Amy</td><td>876</td></tr><tr><td>Hermes</td><td>779</td></tr><tr><td>Zapp Brannigan</td><td>498</td></tr><tr><td>Kif</td><td>252</td></tr><tr><td>Mom</td><td>185</td></tr><tr><td>Calculon</td><td>165</td></tr><tr><td>Lrrr</td><td>148</td></tr><tr><td>Cubert</td><td>146</td></tr><tr><td>Richard Nixon's Head</td><td>145</td></tr><tr><td>Nibbler</td><td>105</td></tr><tr><td>Robot Devil</td><td>90</td></tr><tr><td>Mr. Wong</td><td>90</td></tr><tr><td>Dwight</td><td>86</td></tr><tr><td>Morbo</td><td>76</td></tr><tr><td>Elzar</td><td>75</td></tr><tr><td>Linda</td><td>73</td></tr><tr><td>URL</td><td>72</td></tr><tr><td>Man</td><td>72</td></tr><tr><td>LaBarbara</td><td>72</td></tr><tr><td>Wernstrom</td><td>71</td></tr><tr><td>Nudar</td><td>62</td></tr><tr><td>Walt</td><td>61</td></tr><tr><td>Donbot</td><td>58</td></tr><tr><td>Scruffy</td><td>57</td></tr><tr><td>Sal</td><td>53</td></tr><tr><td>Announcer</td><td>51</td></tr><tr><td>Bender's ghost</td><td>51</td></tr><tr><td>Smitty</td><td>50</td></tr><tr><td>Clamps</td><td>49</td></tr><tr><td>Roberto</td><td>49</td></tr><tr><td>Coilette</td><td>48</td></tr><tr><td>Narrator</td><td>47</td></tr><tr><td>Poopenmeyer</td><td>46</td></tr><tr><td>Tate</td><td>46</td></tr><tr><td>Nine</td><td>46</td></tr><tr><td>Alcazar</td><td>44</td></tr><tr><td>Beck</td><td>42</td></tr><tr><td>Lars</td><td>42</td></tr><tr><td>Titanius Anglesmith</td><td>42</td></tr><tr><td>Santa</td><td>40</td></tr><tr><td>Larry</td><td>39</td></tr><tr><td>Michelle</td><td>38</td></tr><tr><td>Morgan</td><td>38</td></tr><tr><td>Ship</td><td>38</td></tr><tr><td>Hedonism Bot</td><td>37</td></tr><tr><td>Fry-2</td><td>37</td></tr><tr><td>Hutch</td><td>37</td></tr><tr><td>Flexo</td><td>36</td></tr><tr><td>Frydo</td><td>36</td></tr><tr><td>Woman</td><td>35</td></tr><tr><td>Steve Castle</td><td>35</td></tr><tr><td>Greyfarn</td><td>35</td></tr><tr><td>ALL</td><td>34</td></tr><tr><td>Igner</td><td>34</td></tr><tr><td>Preacherbot</td><td>33</td></tr><tr><td>Mrs. Wong</td><td>33</td></tr><tr><td>Munda</td><td>33</td></tr><tr><td>Nimoy</td><td>32</td></tr><tr><td>Hattie</td><td>32</td></tr><tr><td>Yivo</td><td>32</td></tr><tr><td>Nd-Nd</td><td>31</td></tr><tr><td>Zoid</td><td>31</td></tr><tr><td>Melllvar</td><td>30</td></tr><tr><td>Man #1</td><td>29</td></tr><tr><td>Angle-ine</td><td>29</td></tr><tr><td>Shatner</td><td>29</td></tr><tr><td>Morris</td><td>28</td></tr><tr><td>Colleen</td><td>28</td></tr><tr><td>Leegola</td><td>28</td></tr><tr><td>Tinny Tim</td><td>27</td></tr><tr><td>Gore</td><td>27</td></tr><tr><td>Waterfall Sr.</td><td>27</td></tr><tr><td>Adlai</td><td>27</td></tr><tr><td>Albert</td><td>27</td></tr><tr><td>Ndnd</td><td>27</td></tr><tr><td>Crowd</td><td>26</td></tr><tr><td>Salesman</td><td>26</td></tr><tr><td>Hyper-Chicken</td><td>26</td></tr><tr><td>Farnsworth 1</td><td>26</td></tr><tr><td>Petunia</td><td>25</td></tr><tr><td>Yancy</td><td>25</td></tr><tr><td>Ken</td><td>25</td></tr><tr><td>Dr. Perceptron</td><td>25</td></tr><tr><td>Glurmo</td><td>24</td></tr><tr><td>Raoul</td><td>24</td></tr><tr><td>Farnsworth-Droid</td><td>23</td></tr><tr><td>Farnsworth A</td><td>23</td></tr><tr><td>Dwayne</td><td>22</td></tr><tr><td>Waterfall Jr.</td><td>22</td></tr><tr><td>Frida</td><td>22</td></tr><tr><td>Randy</td><td>21</td></tr><tr><td>Guenter</td><td>21</td></tr><tr><td>Gypsy</td><td>21</td></tr><tr><td>Big Brain</td><td>21</td></tr><tr><td>Mrs. Astor</td><td>21</td></tr><tr><td>Abner Doubledeal</td><td>21</td></tr><tr><td>Man #2</td><td>20</td></tr><tr><td>Edna</td><td>20</td></tr><tr><td>Thog</td><td>20</td></tr><tr><td>Big rock Alien</td><td>20</td></tr><tr><td>Yancy Fry Sr</td><td>20</td></tr><tr><td>Panucci</td><td>19</td></tr><tr><td>Robot</td><td>19</td></tr><tr><td>Sally</td><t ...

# %%
# double check that there aren't examples of same name different case:
speakerExistsLookup = {}
duplicatesFound = False
for speaker in speakers:
    if speaker["SPEAKER"].lower() in speakerExistsLookup:
        print(f"Duplicate found: {speaker['SPEAKER']}")
        duplicatesFound = True
    else:
        speakerExistsLookup[speaker["SPEAKER"].lower()] = True

if not duplicatesFound:
    print("No duplicates found this time.")
# Out:
# No duplicates found this time.
